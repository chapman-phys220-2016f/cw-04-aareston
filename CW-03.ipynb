# %% [markdown]
# # Classwork 3
# ## Aaron Grisez and Preston Kamada

# %%
import pi_sequences

# %% [markdown]
# ### Problem 2
#
# Approximate pi by implementing 5 different sequences which converge to pi. Find the one to converge the fastest.
#
# The test sequences are as follows:
# $$ a_{n} = 4 \sum_{k = 1}^{n}\frac{(-1)^{k+1}}{2k-1}$$
# $$ b_{n} = \left( 6\sum_{k = 1}^{n}k^{-2}\right)^\frac{1}{2}$$
# $$ c_{n} = \left( 90\sum_{k = 1}^{n}k^{-4}\right)^\frac{1}{4}$$
# $$ d_{n} = \frac{6}{\sqrt{3}}\sum_{k = 0}^{n} \frac{(-1)^k}{3^k(2k+1)}$$
# $$ e_{n} = 16 \sum_{k = 0}^{n}\frac{(-1)^k}{5^{2k+1}(2k+1)} - 4\sum_{k = 0}^{n} \frac{(-1)^k}{239^{

# %%
pi_sequences.plot_sequences()
